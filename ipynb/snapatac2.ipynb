# %%
import snapatac2 as snap
import scanpy as sc
import matplotlib.pyplot as plt

# %%
gene_annotation = "/media/chang/HDD-1/reference_cellranger/gencode.v39.basic.annotation.gff3.gz"

# %%
files = [
    "/media/chang/HDD-6/chang/mg/GW18_multiome/outs/atac_fragments.tsv.gz",
    "/media/chang/HDD-6/chang/mg/GW22_multiome/outs/atac_fragments.tsv.gz",
    "/media/chang/HDD-6/chang/mg/atac/gw_mg2_atac_cr/outs/fragments.tsv.gz",
    "/media/chang/HDD-6/chang/mg/atac/gw_mg1_atac_cr/outs/fragments.tsv.gz",
]
names = ["GW18_multi","GW22_multi","MG2","MG1"]

# %%
datasets = {}
for fl, name in zip(files, names):
    data = snap.pp.import_data(
        fl,
        gene_annotation,
        snap.genome.hg38,
        sorted_by_barcode = False,
        min_num_fragments = 5000,
        output = "/media/chang/HDD-6/chang/mg/atac/" + name + ".h5ad",
    )
    snap.pp.filter_cells(data, min_tsse = 10, max_counts=50000)
    snap.pp.make_tile_matrix(data)
    snap.pp.select_features(data)
    snap.pp.scrublet(data)
    snap.pp.call_doublets(data)
    datasets[name] = data
datasets
# Out:
# Simulating doublets...
# Spectral embedding ...
# Compute similarity matrix
# Normalization
# Perform decomposition
# Calculating doublet scores...
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/sklearn/utils/validation.py:593: FutureWarning:
#
# np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
# Simulating doublets...
# Spectral embedding ...
# Compute similarity matrix
# Normalization
# Perform decomposition

# %%
datasets
# Out:
# {'GW18_multi': AnnData object with n_obs × n_vars = 10453 × 6176550 backed at '/media/chang/HDD-6/chang/mg/atac/GW18_multi.h5ad'
#      obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_score', 'is_doublet'
#      var: 'selected'
#      uns: 'scrublet'
#      obsm: 'base_count',
#  'GW22_multi': AnnData object with n_obs × n_vars = 19471 × 6176550 backed at '/media/chang/HDD-6/chang/mg/atac/GW22_multi.h5ad'
#      obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_score', 'is_doublet'
#      var: 'selected'
#      uns: 'scrublet'
#      obsm: 'base_count',
#  'MG2': AnnData object with n_obs × n_vars = 20652 × 6176550 backed at '/media/chang/HDD-6/chang/mg/atac/MG2.h5ad'
#      obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_score', 'is_doublet'
#      var: 'selected'
#      uns: 'scrublet'
#      obsm: 'base_count',
#  'MG1': AnnData object with n_obs × n_vars = 4867 × 6176550 backed at '/media/chang/HDD-6/chang/mg/atac/MG1.h5ad'
# ...

# %%
snap.pp.call_doublets(datasets["GW22_multi"], .2)
snap.pl.scrublet(datasets["GW22_multi"], interactive=False)
datasets["GW22_multi"] = datasets["GW22_multi"][datasets["GW22_multi"].obs["is_doublet"] == False]

# %%
snap.pl.tsse(datasets["GW22_multi"], show_cells=True, interactive=False)

# %%
snap.pp.call_doublets(datasets["GW18_multi"], .3)
snap.pl.scrublet(datasets["GW18_multi"], interactive=False)
datasets["GW18_multi"] = datasets["GW18_multi"][datasets["GW18_multi"].obs["is_doublet"] == False]

# %%
snap.pl.tsse(datasets["GW18_multi"], show_cells=True, interactive=False)

# %%
snap.pp.call_doublets(datasets["MG2"], .2)
snap.pl.scrublet(datasets["MG2"], interactive=False)
datasets["MG2"] = datasets["MG2"][datasets["MG2"].obs["is_doublet"] == False]

# %%
snap.pl.tsse(datasets["MG2"], show_cells=True, interactive=False)

# %%
snap.pp.call_doublets(datasets["MG1"], .3)
snap.pl.scrublet(datasets["MG1"], interactive=False)
datasets["MG1"] = datasets["MG1"][datasets["MG1"].obs["is_doublet"] == False]

# %%
snap.pl.tsse(datasets["MG1"], show_cells=True, interactive=False)

# %%
data = snap.create_ann_collection(
    datasets,
    index_unique = "_",
    label = "batch",
)
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 data = snap.create_ann_collection(
#       2     datasets,
#       3     index_unique = "_",
#       4     label = "batch",
#       5 )
#       6 data
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/snapatac2/_utils.py:76, in create_ann_collection(adatas, join_obs, join_obsm, join_vars, label, keys, index_unique, convert, harmonize_dtypes, indices_strict)
#      73 import pandas as pd
#      74 from anndata._core.aligned_mapping import AxisArrays
# ---> 76 data = AnnCollection(
#      77     adatas,
#      78     join_obs,
#      79     join_obsm,
#      80     join_vars,
#      81     label,
#      82     keys,
#      83     index_unique,
#      84     convert,
#      85     harmonize_dtypes,
#      86     indices_strict,
#      87 )
#      88 data.var = pd.DataFrame()
# ...

# %%
#data = data[data.obs["is_doublet"] == False]
data
# Out:
# AnnCollection object with n_obs × n_vars = 55443 × 6176550
#   constructed from 4 AnnData objects
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_score', 'is_doublet', 'batch'

# %%
snap.pp.select_features(data, blacklist="/home/chang/ENCFF356LFX.bed")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [77], in <cell line: 1>()
# ----> 1 snap.pp.select_features(data, blacklist="/home/chang/ENCFF356LFX.bed")
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/snapatac2/preprocessing/_basic.py:272, in select_features(adata, variable_feature, whitelist, blacklist, inplace)
#     269     selected_features &= np.absolute((count - mean) / std) < 1.65
#     271 if inplace:
# --> 272     adata.var["selected"] = selected_features
#     273 else:
#     274     return selected_features
#
# AttributeError: 'AnnCollectionView' object has no attribute 'var'

# %%
snap.tl.spectral(data)

# %%
snap.pl.spectral_eigenvalues(data, interactive=False)

# %%
data = data.to_adata()

# %%
# Perform UMAP
snap.tl.umap(data, use_dims = 12)
sc.pl.umap(data, color="batch")

# %%
fragment_file = "/media/chang/HDD-6/chang/mg/GW18_multiome/outs/atac_fragments.tsv.gz"

# %%
data = snap.pp.import_data(
    fragment_file,
    gene_annotation,
    snap.genome.hg38,
    sorted_by_barcode = False,
    min_num_fragments = 5000,
    output = '/media/chang/HDD-6/chang/mg/GW18_multiome/outs/data.h5ad',
    n_jobs = 16
)

# %%
data = snap.read('/media/chang/HDD-6/chang/mg/GW18_multiome/outs/data.h5ad',backed='r+')
snap.pl.tsse(data, show_cells=True, interactive=False)

# %%
snap.pp.filter_cells(data, min_counts=5000, min_tsse=10, max_counts=50000)
data
# Out:
# AnnData object with n_obs × n_vars = 10453 × 0 backed at '/media/chang/HDD-6/chang/mg/GW18_multiome/outs/data.h5ad'
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito'
#     obsm: 'base_count'

# %%
snap.pp.make_tile_matrix(data)

# %%
snap.pp.select_features(data, blacklist="/home/chang/ENCFF356LFX.bed")
data
# Out:
# AnnData object with n_obs × n_vars = 10453 × 6176550 backed at '/media/chang/HDD-6/chang/mg/GW18_multiome/outs/data.h5ad'
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito'
#     var: 'selected'
#     obsm: 'base_count'

# %%
snap.pp.scrublet(data)
# Out:
# Simulating doublets...
# Spectral embedding ...
# Compute similarity matrix
# Normalization
# Perform decomposition
# Calculating doublet scores...
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/sklearn/utils/validation.py:593: FutureWarning: np.matrix usage is deprecated in 1.0 and will raise a TypeError in 1.2. Please convert to a numpy array with np.asarray. For more information see: https://numpy.org/doc/stable/reference/generated/numpy.matrix.html
#   warnings.warn(

# %%
snap.pp.call_doublets(data, .2)
snap.pl.scrublet(data, interactive=False)

# %%
data = data[data.obs["is_doublet"] == False]

# %%
data
# Out:
# AnnData object with n_obs × n_vars = 8014 × 6176550 backed at '/media/chang/HDD-6/chang/mg/GW18_multiome/outs/data.h5ad'
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_score', 'is_doublet'
#     var: 'selected'
#     uns: 'scrublet'
#     obsm: 'base_count'

# %%
snap.tl.spectral(data)
# Out:
# Compute similarity matrix
# Normalization
# Perform decomposition

# %%
snap.pl.spectral_eigenvalues(data, interactive=False)

# %%
snap.tl.umap(data, use_dims=15)

# %%
snap.pp.knn(data, use_dims=15)
snap.tl.leiden(data)
snap.tl.leiden(data, objective_function="CPM", resolution=0.035, min_cluster_size=20, key_added="leiden_CPM")
snap.tl.kmeans(data, 12)

# %%
import scanpy as sc
sc.pl.umap(data, color=["leiden", "leiden_CPM", "kmeans"])

# %%
gene_matrix = snap.pp.make_gene_matrix(data, gene_annotation)

# %%
sc.pp.filter_genes(gene_matrix, min_cells= 5)
sc.pp.normalize_total(gene_matrix)
sc.pp.log1p(gene_matrix)

# %%
sc.external.pp.magic(gene_matrix, solver="approximate")
# Out:
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/magic/utils.py:145: FutureWarning:
#
# X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.

# %%
gene_matrix.obsm["X_umap"] = data.obsm["X_umap"]

# %%
marker_genes = ['GPNMB', 'P2RY13', 'MRC1', 'CCL3', 'LYZ', 'MKI67', 'LGALS3']

sc.pl.umap(gene_matrix, use_raw=False, color=["leiden"] + marker_genes)
sc.pl.violin(gene_matrix, marker_genes, use_raw=False, groupby='leiden')

# %%
data
# Out:
# AnnData object with n_obs × n_vars = 8014 × 6176550 backed at '/media/chang/HDD-6/chang/mg/GW18_multiome/outs/data.h5ad'
#     obs: 'tsse', 'n_fragment', 'frac_dup', 'frac_mito', 'doublet_score', 'is_doublet', 'leiden', 'leiden_CPM', 'kmeans'
#     var: 'selected'
#     uns: 'scrublet', 'spectral_eigenvalue', 'leiden', 'kmeans', 'leiden_colors', 'leiden_CPM_colors', 'kmeans_colors'
#     obsm: 'base_count', 'X_spectral', 'X_umap'
#     obsp: 'distances'
