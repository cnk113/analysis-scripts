# %%
import cospar as cs
import scanpy as sc
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import os
os.environ['QT_QPA_PLATFORM']='offscreen'

# %%
#sc.settings.set_figure_params(dpi=100, facecolor='white')
cs.settings.set_figure_params()

# %%
adata = sc.read('/home/chang/data_dir/data2.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 2680 × 58302
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'nCount_bc', 'nFeature_bc', 'percent.mt', 'nCount_SCT', 'nFeature_SCT', 'SCT_snn_res.0.6', 'seurat_clusters', 'SCT_snn_res.0.8', 'clusters', 'calls', 'Sample', 'Clonoclusters.1', 'Clonoclusters.0', 'Clonoclusters'
#     obsm: 'X_pca', 'X_umap'

# %%
cs.pp.get_X_clone(adata,adata.obs.index.tolist(),adata.obs.calls.tolist())
adata.obs['state_info'] = adata.obs['Clonoclusters.0']
adata.obs["state_info"] = pd.Categorical(df.cc)
adata.uns["data_des"] = "/home/chang/data_dir/cospar"
adata.obs["time_info"] = 0
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 2680/2680 [00:00<00:00, 1578754.88it/s]

# %%
cycling_gene_list=['Ube2c', 'Hmgb2', 'Hmgn2', 'Tuba1b', 'Ccnb1', 'Tubb5', 'Top2a', 'Tubb4b']
cycling_gene_list = [x.upper() for x in cycling_gene_list]
cycling_gene_list
# Out:
# ['UBE2C', 'HMGB2', 'HMGN2', 'TUBA1B', 'CCNB1', 'TUBB5', 'TOP2A', 'TUBB4B']

# %%
#cs.pp.get_highly_variable_genes(adata)
#cs.pp.remove_cell_cycle_correlated_genes(adata,cycling_gene_list)
#cs.pp.get_X_pca(adata)
#cs.pp.get_X_emb(adata)

# %%
adata.obsm['X_emb'] = adata.obsm['X_umap']

# %%
sc.pl.umap(adata,  color=['clusters', 'orig.ident',"Clonoclusters.0"])

# %%
cs.pl.barcode_heatmap(adata,selected_times=None,
        color_bar=True,log_transform=False,binarize=True)
# Out:
# Data saved at adata.uns['barcode_heatmap']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 cs.pl.barcode_heatmap(adata,selected_times=None,
#       2         color_bar=True,log_transform=False,binarize=True)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/cospar-0.2.1-py3.8.egg/cospar/plotting/_clone.py:164, in barcode_heatmap(adata, selected_times, selected_fates, color_bar, rename_fates, normalize, binarize, log_transform, fig_width, fig_height, figure_index, plot, pseudocount, order_map_x, order_map_y, fate_normalize_source, select_clones_with_fates, select_clones_without_fates, select_clones_mode, **kwargs)
#     162 if figure_index != "":
#     163     figure_index == f"_{figure_index}"
# --> 164 plt.savefig(
#     165     os.path.join(
#     166         figure_path,
#     167         f"{data_des}_barcode_heatmap{figure_index}.{settings.file_format_figs}",
#     168     )
#     169 )
#     170 return ax
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:977, in savefig(*args, **kwargs)
#     974 @_copy_docstring_and_deprecators(Figure.savefig)
#     975 def savefig(*args, **kwargs):
#     976     fig = gcf()
# --> 977     res = fig.savefig(*args, **kwargs)
#     978     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     979     return res
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/figure.py:3058, in Figure.savefig(self, fname, transparent, **kwargs)
#    3054     for ax in self.axes:
#    3055         stack.enter_context(
#    3056             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3058 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:389, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     384 @functools.wraps(func)
#     385 def wrapper(*inner_args, **inner_kwargs):
#     386     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     387         # Early return in the simple, non-deprecated case (much faster than
#     388         # calling bind()).
# --> 389         return func(*inner_args, **inner_kwargs)
#     390     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     391     if is_varargs and arguments.get(name):
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:2783, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2781     file = filename._file
#    2782 else:
# -> 2783     file = PdfFile(filename, metadata=metadata)
#    2784 try:
#    2785     file.newPage(width, height)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figure/r_clonal_barcode_heatmap.pdf'

# %%
cs.tl.fate_coupling(adata,source='X_clone') # compute the fate coupling
cs.pl.fate_coupling(adata,source='X_clone') # actually plot the coupling
# Out:
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# Results saved as dictionary at adata.uns['fate_coupling_X_clone']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [37], line 2
#       1 cs.tl.fate_coupling(adata,source='X_clone') # compute the fate coupling
# ----> 2 cs.pl.fate_coupling(adata,source='X_clone')
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/cospar-0.2.1-py3.8.egg/cospar/plotting/_map.py:101, in fate_coupling(adata, source, color_bar, rename_fates, color_map, figure_index, color_bar_label, vmax, **kwargs)
#      99 if figure_index != "":
#     100     figure_index == f"_{figure_index}"
# --> 101 plt.savefig(
#     102     os.path.join(
#     103         figure_path,
#     104         f"{data_des}_{key_word}{figure_index}.{settings.file_format_figs}",
#     105     )
#     106 )
#     107 return ax
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/pyplot.py:977, in savefig(*args, **kwargs)
#     974 @_copy_docstring_and_deprecators(Figure.savefig)
#     975 def savefig(*args, **kwargs):
#     976     fig = gcf()
# --> 977     res = fig.savefig(*args, **kwargs)
#     978     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     979     return res
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/figure.py:3058, in Figure.savefig(self, fname, transparent, **kwargs)
#    3054     for ax in self.axes:
#    3055         stack.enter_context(
#    3056             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3058 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:389, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     384 @functools.wraps(func)
#     385 def wrapper(*inner_args, **inner_kwargs):
#     386     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     387         # Early return in the simple, non-deprecated case (much faster than
#     388         # calling bind()).
# --> 389         return func(*inner_args, **inner_kwargs)
#     390     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     391     if is_varargs and arguments.get(name):
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:2783, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2781     file = filename._file
#    2782 else:
# -> 2783     file = PdfFile(filename, metadata=metadata)
#    2784 try:
#    2785     file.newPage(width, height)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figure/r_fate_coupling_X_clone.pdf'

# %%
cs.tl.fate_hierarchy(adata,source='X_clone') # compute the fate hierarchy
cs.pl.fate_hierarchy(adata,source='X_clone') # actually plot the hierarchy
# Out:
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# normalize by X_clone
# each selected cluster has a unique time point. Normalize per time point
# Results saved as dictionary at adata.uns['fate_hierarchy_X_clone']
#
#                      /-3
#                   /-|
#                /-|   \-0
#               |  |
#             /-|   \-4
#            |  |
#          /-|   \-2
#         |  |
#       /-|   \-5
#      |  |
#    /-|   \-6
#   |  |
#   |   \-9
#   |
#   |            /-10
# --|         /-|
#   |      /-|   \-7
#   |     |  |
#   |   /-|   \-1
#   |  |  |
#    \-|   \-8
#      |
#       \-11

# %%
my_tree_refined = adata.uns["fate_hierarchy_X_clone"]["tree"]
my_tree_refined
# Out:
# Tree node '' (0x7f4cf7810bb)

# %%
cs.settings.figure_path
# Out:
# 'figure'

# %%
cs.pl.visualize_tree(
    my_tree_refined,
    color_coding=None,
    mode="r",
    data_des=f"my_tree",
    figure_path="/home/chang/data_dir/cospar",
    dpi=100
)

# %%
cs.tl.clonal_fate_bias(adata,selected_fate=9,alternative='two-sided') # compute the fate hierarchy
cs.pl.clonal_fate_bias(adata) # actually plot the hierarchy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [48], line 1
# ----> 1 cs.tl.clonal_fate_bias(adata,selected_fate=9,alternative='two-sided') # compute the fate hierarchy
#       2 cs.pl.clonal_fate_bias(adata)
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/cospar-0.2.1-py3.8.egg/cospar/tool/_clone.py:74, in clonal_fate_bias(adata, selected_fate, alternative)
#      66 if type(selected_fate) == str:
#      67     selected_fate = [selected_fate]
#      69 (
#      70     mega_cluster_list,
#      71     valid_fate_list,
#      72     fate_array_flat,
#      73     sel_index_list,
# ---> 74 ) = hf.analyze_selected_fates(state_info, selected_fate)
#      75 if len(mega_cluster_list) == 0:
#      76     logg.error("No cells selected. Computation aborted!")
#
# File ~/miniconda3/envs/venv/lib/python3.8/site-packages/cospar-0.2.1-py3.8.egg/cospar/help_functions/_help_functions_CoSpar.py:644, in analyze_selected_fates(state_info, selected_fates)
#     642 mega_cluster_list = []  # a list of string description for the macro cluster
#     643 sel_index_list = []
# --> 644 for xx in selected_fates:
#     645     if type(xx) is list:
#     646         valid_fate_list.append(xx)
#
# TypeError: 'int' object is not iterable

# %%
result=adata.uns['clonal_fate_bias']
result
# Out:
#      Clone_ID  Clone_size       Q_value  Fate_bias  \
# 0         167          78  3.029219e-11  10.518669
# 1         289          17  5.388161e-10   9.268559
# 2         321          28  5.823002e-07   6.234853
# 3          19          15  5.823002e-07   6.234853
# 4         333          99  9.783481e-07   6.009507
# ..        ...         ...           ...        ...
# 333       121           4  1.000000e+00  -0.000000
# 334       120          14  1.000000e+00  -0.000000
# 335       119           3  1.000000e+00  -0.000000
# 336       126           4  1.000000e+00  -0.000000
# 337       337           9  1.000000e+00  -0.000000
#
#      clonal_fraction_in_target_fate
# 0                          0.410256
# 1                          0.823529
# 2                          0.535714
# 3                          0.733333
# 4                          0.292929
# ..                              ...
# 333                        0.000000
# 334                        0.000000
# 335                        0.000000
# 336                        0.000000
# 337                        0.000000
#
# [338 rows x 5 columns]

# %%
ids=result['Clone_ID'][0:]
cs.pl.clones_on_manifold(adata,selected_clone_list=ids,color_list=['black','red','blue'],clone_markersize=10,)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [71], in <cell line: 2>()
#       1 ids=result['Clone_ID'][0:]
# ----> 2 cs.pl.clones_on_manifold(adata,selected_clone_list=ids,color_list=['black','red','blue'],clone_markersize=10,)
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/cospar/plotting/_clone.py:299, in clones_on_manifold(adata, selected_clone_list, color_list, selected_times, title, clone_markersize, clone_markeredgewidth, **kwargs)
#     296     if title:
#     297         ax.set_title(f"ID: {my_id}")
# --> 299 fig.savefig(
#     300     os.path.join(
#     301         figure_path,
#     302         f"{data_des}_different_clones_{my_id}.{settings.file_format_figs}",
#     303     )
#     304 )
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/figure.py:3019, in Figure.savefig(self, fname, transparent, **kwargs)
#    3015     for ax in self.axes:
#    3016         stack.enter_context(
#    3017             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3019 self.canvas.print_figure(fname, **kwargs)
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/_api/deprecation.py:386, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     381 @functools.wraps(func)
#     382 def wrapper(*inner_args, **inner_kwargs):
#     383     if len(inner_args) <= name_idx and name not in inner_kwargs:
#     384         # Early return in the simple, non-deprecated case (much faster than
#     385         # calling bind()).
# --> 386         return func(*inner_args, **inner_kwargs)
#     387     arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     388     if is_varargs and arguments.get(name):
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:2778, in FigureCanvasPdf.print_pdf(self, filename, dpi, bbox_inches_restore, metadata)
#    2776     file = filename._file
#    2777 else:
# -> 2778     file = PdfFile(filename, metadata=metadata)
#    2779 try:
#    2780     file.newPage(width, height)
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/backends/backend_pdf.py:654, in PdfFile.__init__(self, filename, metadata)
#     652 self.original_file_like = None
#     653 self.tell_base = 0
# --> 654 fh, opened = cbook.to_filehandle(filename, "wb", return_opened=True)
#     655 if not opened:
#     656     try:
#
# File ~/miniconda3/envs/venv3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:451, in to_filehandle(fname, flag, return_opened, encoding)
#     449         fh = bz2.BZ2File(fname, flag)
#     450     else:
# --> 451         fh = open(fname, flag, encoding=encoding)
#     452     opened = True
#     453 elif hasattr(fname, 'seek'):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'figure/r_different_clones_167.pdf'

# %%
gw15_rep1=cs.tmap.infer_Tmap_from_clonal_info_alone(gw15_rep1,method='weinreb',later_time_point='6',selected_fates=selected_fates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [74], in <cell line: 1>()
# ----> 1 gw15_rep1=cs.tmap.infer_Tmap_from_clonal_info_alone(gw15_rep1,method='weinreb',later_time_point='6',selected_fates=selected_fates)
#
# NameError: name 'gw15_rep1' is not defined

# %%
cs.tl.fate_coupling(adata,selected_fates=selected_fates,source='transition_map')
cs.pl.fate_coupling(adata,source='transition_map')

# %%
cs.tl.fate_hierarchy(adata,selected_fates=selected_fates,source='transition_map')
cs.pl.fate_hierarchy(adata,source='transition_map')
