# %%
import scanpy as sc
import numpy as np
import pandas as pd
import diopy
import matplotlib.pyplot as plt

# %%
sc.__version__
# Out:
# '1.9.1'

# %%
adata = sc.read_10x_h5("/media/chang/HDD-9/chang/merged1.h5")
for filename in ["/media/chang/HDD-9/chang/merged2.h5","/media/chang/HDD-9/chang/merged3.h5"]:
    tmp = sc.read_10x_h5(filename)
    adata = adata.concatenate(tmp, index_unique=None)
adata
# Out:
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/scanpy/readwrite.py:281: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = AnnData(
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/scanpy/readwrite.py:281: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   adata = AnnData(
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/anndata/_core/anndata.py:1785: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   [AnnData(sparse.csr_matrix(a.shape), obs=a.obs) for a in all_adatas],
# AnnData object with n_obs × n_vars = 2682875 × 37481
#     obs: 'batch'
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
#adata.write("/media/chang/HDD-9/chang/merged.h5ad")

# %%
diopy.output.write_h5(adata, file = '/media/chang/HDD-9/chang/merged.h5')

# %%
adata = sc.read("/media/chang/HDD-9/chang/merged.h5ad")

# %%
ribo_url = "http://software.broadinstitute.org/gsea/msigdb/download_geneset.jsp?geneSetName=KEGG_RIBOSOME&fileType=txt"
ribo_genes = pd.read_table(ribo_url, header=[1]).iloc[:, 0].values.tolist()
ribo_genes.extend(adata.var.gene_ids[adata.var_names.str.startswith('MT-')].values.tolist())
ribo_genes.extend(adata.var.gene_ids[adata.var_names.str.startswith('MALAT')].values.tolist())
ribo_genes = pd.DataFrame({'col':ribo_genes})


ribo_mk = np.in1d(adata.var_names.values.astype(str), ribo_genes)
adata = adata[:,~ribo_mk]
sc.pp.filter_genes(adata, min_cells=10)
adata.X = np.rint(adata.X)
adata.X
# Out:
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:251: ImplicitModificationWarning: Trying to modify attribute `.var` of view, initializing view as actual.
#   adata.var['n_cells'] = number
# <2682875x36021 sparse matrix of type '<class 'numpy.float32'>'
# 	with 4866996596 stored elements in Compressed Sparse Row format>

# %%
sc.experimental.pp.recipe_pearson_residuals(adata,chunksize=1000,n_top_genes=3000,n_comps=100)

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 6))
hvgs = adata.var["highly_variable"]

ax.scatter(
    adata.var["means"], adata.var["residual_variances"], s=3, edgecolor="none"
)
ax.scatter(
    adata.var["means"][hvgs],
    adata.var["residual_variances"][hvgs],
    c="tab:red",
    label="selected genes",
    s=3,
    edgecolor="none",
)
ax.set_xscale("log")
ax.set_xlabel("mean expression")
ax.set_yscale("log")
ax.set_ylabel("residual variance")

ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.yaxis.set_ticks_position("left")
ax.xaxis.set_ticks_position("bottom")
plt.legend()

# %%
sc.pl.pca_variance_ratio(adata, log=True, n_pcs=100)

# %%
sc.pp.neighbors(adata, n_pcs=100)
sc.tl.umap(adata)
# Out:
# /home/chang/miniconda3/envs/venv3.8/lib/python3.8/site-packages/sklearn/manifold/_spectral_embedding.py:259: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
adata.obs = pd.read_csv('/media/chang/HDD-9/chang/meta.csv',header=0)
adata.obs
# Out:
# /tmp/ipykernel_1897427/431153084.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   adata.obs = pd.read_csv('/media/chang/HDD-9/chang/meta.csv',header=0)
#                                orig.ident    nCount_RNA  nFeature_RNA  \
# CGE_GW18_2_AAACCTGAGACATAAC_1  CGE_GW18_2  20255.000022          5633
# CGE_GW18_2_AAACCTGAGCCCGAAA_1  CGE_GW18_2  45071.000074          7242
# CGE_GW18_2_AAACCTGAGGGTCGAT_1  CGE_GW18_2  16083.999970          4402
# CGE_GW18_2_AAACCTGCAAGCCATT_1  CGE_GW18_2   3147.999999          1540
# CGE_GW18_2_AAACCTGCAAGGACTG_1  CGE_GW18_2   2138.999999          1274
# ...                                   ...           ...           ...
# GW30_V1_TTTGGTTCATGTTGAC_9        GW30_V1   1292.000001           794
# GW30_V1_TTTGGTTTCTTTACAC_9        GW30_V1   1367.999975           921
# GW30_V1_TTTGGTTTCTTTCCTC_9        GW30_V1   1850.000004          1204
# GW30_V1_TTTGTCACAGATAATG_9        GW30_V1   4568.000002          2047
# GW30_V1_TTTGTCATCCGAATGT_9        GW30_V1   1642.999996           916
#
#                                     ident     cxds_score  bcds_score  \
# CGE_GW18_2_AAACCTGAGACATAAC_1  CGE_GW18_2  154682.977352    0.425893
# CGE_GW18_2_AAACCTGAGCCCGAAA_1  CGE_GW18_2  244955.877459    0.834519
# CGE_GW18_2_AAACCTGAGGGTCGAT_1  CGE_GW18_2   33535.970212    0.104484
# CGE_GW18_2_AAACCTGCAAGCCATT_1  CGE_GW18_2  114804.455934    0.006750
# CGE_GW18_2_AAACCTGCAAGGACTG_1  CGE_GW18_2    6281.162128    0.001473
# ...                                   ...            ...         ...
# GW30_V1_TTTGGTTCATGTTGAC_9        GW30_V1   11558.478488    0.071955
# GW30_V1_TTTGGTTTCTTTACAC_9        GW30_V1   13886.202521    0.098877
# GW30_V1_TTTGGTTTCTTTCCTC_9        GW30_V1   17518.435397    0.130244
# GW30_V1_TTTGTCACAGATAATG_9        GW30_V1   44771.493509    0.909881
# GW30_V1_TTTGTCATCCGAATGT_9        GW30_V1   13127.961160    0.175460
#
#                                hybrid_score  nCount_spliced  nFeature_spliced  \
# CGE_GW18_2_AAACCTGAGACATAAC_1      0.793150           15639              3970
# CGE_GW18_2_AAACCTGAGCCCGAAA_1      1.417413           38678              5967
# CGE_GW18_2_AAACCTGAGGGTCGAT_1      0.183534           13770              3535
# CGE_GW18_2_AAACCTGCAAGCCATT_1      0.277504            2332              1026
# CGE_GW18_2_AAACCTGCAAGGACTG_1      0.015525            2030              1178
# ...                                     ...             ...               ...
# GW30_V1_TTTGGTTCATGTTGAC_9         0.135449             830               486
# GW30_V1_TTTGGTTTCTTTACAC_9         0.194331             845               524
# GW30_V1_TTTGGTTTCTTTCCTC_9         0.273813            1216               748
# GW30_V1_TTTGTCACAGATAATG_9         1.504266            3352              1334
# GW30_V1_TTTGTCATCCGAATGT_9         0.274586            1215               644
#
#                                nCount_unspliced  nFeature_unspliced  \
# CGE_GW18_2_AAACCTGAGACATAAC_1              3667                1995
# CGE_GW18_2_AAACCTGAGCCCGAAA_1              3221                1911
# CGE_GW18_2_AAACCTGAGGGTCGAT_1              1512                1014
# CGE_GW18_2_AAACCTGCAAGCCATT_1               678                 497
# CGE_GW18_2_AAACCTGCAAGGACTG_1                26                  26
# ...                                         ...                 ...
# GW30_V1_TTTGGTTCATGTTGAC_9                  328                 252
# GW30_V1_TTTGGTTTCTTTACAC_9                  426                 327
# GW30_V1_TTTGGTTTCTTTCCTC_9                  468                 382
# GW30_V1_TTTGTCACAGATAATG_9                  863                 627
# GW30_V1_TTTGTCATCCGAATGT_9                  254                 200
#
#                                percent.mt      Sample Chemistry    Area   Age
# CGE_GW18_2_AAACCTGAGACATAAC_1    4.823500  CGE_GW18_2        v2      GE  GW18
# CGE_GW18_2_AAACCTGAGCCCGAAA_1    2.345189  CGE_GW18_2        v2      GE  GW18
# CGE_GW18_2_AAACCTGAGGGTCGAT_1    3.892067  CGE_GW18_2        v2      GE  GW18
# CGE_GW18_2_AAACCTGCAAGCCATT_1    1.683609  CGE_GW18_2        v2      GE  GW18
# CGE_GW18_2_AAACCTGCAAGGACTG_1    5.329593  CGE_GW18_2        v2      GE  GW18
# ...                                   ...         ...       ...     ...   ...
# GW30_V1_TTTGGTTCATGTTGAC_9       2.786378        GW30        v2  Cortex  GW30
# GW30_V1_TTTGGTTTCTTTACAC_9       1.461988        GW30        v2  Cortex  GW30
# GW30_V1_TTTGGTTTCTTTCCTC_9       1.837838        GW30        v2  Cortex  GW30
# GW30_V1_TTTGTCACAGATAATG_9       0.394046        GW30        v2  Cortex  GW30
# GW30_V1_TTTGTCATCCGAATGT_9       1.825928        GW30        v2  Cortex  GW30
#
# [2682875 rows x 16 columns]

# %%
adata.obs['Area'].value_counts()
# Out:
# Cortex          1288156
# Hypothalamus     423731
# GE               402650
# Cerebellum       139452
# Thalamus         133510
# Hippocampus       96946
# Midbrain          48432
# Forebrain         46298
# Hindbrain         33207
# OL                23184
# total             21550
# CD133             15326
# Brainstem         10433
# Name: Area, dtype: int64

# %%
sc.pl.umap(adata, color=["Age"], cmap="tab20")

# %%
sc.pl.umap(adata, color=['AIF1', 'MKI67', 'HOPX'])#, use_raw=False)

# %%
adata.write("/media/chang/HDD-9/chang/merged_pearson.h5ad")

# %%
adata = sc.read("/media/chang/HDD-9/chang/merged_pearson.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 2682875 × 37481
#     obs: 'batch'
#     var: 'gene_ids', 'feature_types', 'genome', 'means', 'variances', 'residual_variances', 'highly_variable_rank', 'highly_variable'
#     uns: 'hvg', 'pca', 'pearson_residuals_normalization', 'neighbors', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'distances', 'connectivities'
