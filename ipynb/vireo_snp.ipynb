# %%
import numpy as np
import matplotlib.pyplot as plt
import vireoSNP

# %%
#7215-34,3577-3,AB-2,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane1,2,3	3577-3, 6OC2, 28126, 1323-4
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (124074, 3, 3)
# Shape for Geno Prob in VCF2: (124074, 3, 3)
# n_variants in VCF1, VCF2 and matchd: 124074, 162195, 74940
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor0' 'donor3']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane1,2,3	3577-3, 6OC2, 28126, WTC10, 1323-4
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane2/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (124074, 3, 3)
# Shape for Geno Prob in VCF2: (124074, 3, 3)
# n_variants in VCF1, VCF2 and matchd: 124074, 154986, 73906
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor0' 'donor1']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane1,2,3	3577-3, 6OC2, 28126, WTC10, 1323-4
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane3/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (124074, 3, 3)
# Shape for Geno Prob in VCF2: (124074, 3, 3)
# n_variants in VCF1, VCF2 and matchd: 124074, 154462, 71070
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor1' 'donor3']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane1,2,3	3577-3, 6OC2, 28126, 1323-4
#Lane4,5,6,7	28126, 1323-4, 6OC2, 3577-3, 5401-35
#Overlap 3577-3, 6OC2, WTC10, 1323-4, 28126
#Not overlap 5401-35 so its donor 0 in Lane4
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (162195, 4, 3)
# Shape for Geno Prob in VCF2: (162195, 4, 3)
# n_variants in VCF1, VCF2 and matchd: 162195, 164415, 105155
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor3' 'donor1' 'donor4' 'donor2']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane4,5,6,7	28126, 1323-4, 6OC2, 3577-3, 5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC11/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (387543, 9, 3)
# Shape for Geno Prob in VCF2: (387543, 9, 3)
# n_variants in VCF1, VCF2 and matchd: 387543, 164415, 131138
# aligned donors:
# ['donor0' 'donor3' 'donor4' 'donor5' 'donor6']
# ['donor2' 'donor0' 'donor4' 'donor1' 'donor3']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane4,5,6,7	28126, 1323-4, 6OC2, 3577-3, 5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane5/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (162195, 4, 3)
# Shape for Geno Prob in VCF2: (162195, 4, 3)
# n_variants in VCF1, VCF2 and matchd: 162195, 189450, 114693
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor0' 'donor4' 'donor3' 'donor2']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane4,5,6,7	28126, 1323-4, 6OC2, 3577-3, 5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane6/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (162195, 4, 3)
# Shape for Geno Prob in VCF2: (162195, 4, 3)
# n_variants in VCF1, VCF2 and matchd: 162195, 192066, 114504
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor1' 'donor2' 'donor4' 'donor0']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#Lane4,5,6,7	28126, 1323-4, 6OC2, 3577-3, 5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane7/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (162195, 4, 3)
# Shape for Geno Prob in VCF2: (162195, 4, 3)
# n_variants in VCF1, VCF2 and matchd: 162195, 245796, 126666
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor2' 'donor3' 'donor4' 'donor0']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
#28126,6OC2,WTC11
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC11/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (387543, 9, 3)
# Shape for Geno Prob in VCF2: (387543, 9, 3)
# n_variants in VCF1, VCF2 and matchd: 387543, 124074, 96480
# aligned donors:
# ['donor0' 'donor1' 'donor6']
# ['donor2' 'donor0' 'donor1']

# %%
#7215-34,3577-3,AB-2,28126,13234,6OC2,5401-35,20961B
#28126,6OC2,WTC11
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC10/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (411985, 8, 3)
# Shape for Geno Prob in VCF2: (411985, 8, 3)
# n_variants in VCF1, VCF2 and matchd: 411985, 124074, 90560
# aligned donors:
# ['donor1' 'donor3' 'donor6']
# ['donor1' 'donor0' 'donor2']

# %%
#28126,6OC2,WTC11
#Lane1,2,3	3577-3, 6OC2, 28126, 1323-4
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (124074, 3, 3)
# Shape for Geno Prob in VCF2: (124074, 3, 3)
# n_variants in VCF1, VCF2 and matchd: 124074, 162195, 74940
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor2' 'donor0' 'donor3']

# %%
#28126,6OC2,WTC11
#28126,28115,3577-3,5401-35
# Assumption here is that only one should match (28126)
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DSTJN01_10XThalOrgWK10_Apr2021/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/org_1_2/org_1/outs/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (124074, 3, 3)
# Shape for Geno Prob in VCF2: (124074, 3, 3)
# n_variants in VCF1, VCF2 and matchd: 124074, 53976, 33697
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor3' 'donor1' 'donor0']

# %%
# Lane4,5,6,7	28126, 1323-4, 6OC2, 3577-3, 5401-35
# 28126,28115,3577-3,5401-35
# 28126,3577-3,5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/org_1_2/org_1/outs/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 53976, 41893
# aligned donors:
# ['donor0' 'donor2' 'donor3' 'donor4']
# ['donor3' 'donor2' 'donor1' 'donor0']

# %%
#28126,28115,3577-3,5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/org_1_2/org_1/outs/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/org_1_2/org_2/outs/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (53976, 4, 3)
# Shape for Geno Prob in VCF2: (53976, 4, 3)
# n_variants in VCF1, VCF2 and matchd: 53976, 58809, 39657
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor0' 'donor3' 'donor1' 'donor2']

# %%
#28126,28115,3577-3,5401-35
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/org_1_2/org_2/outs/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 58809, 42598
# aligned donors:
# ['donor0' 'donor2' 'donor3' 'donor4']
# ['donor2' 'donor1' 'donor3' 'donor0']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane5/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 189450, 141113
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor1' 'donor4' 'donor2' 'donor0' 'donor3']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane6/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 192066, 141985
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor3' 'donor2' 'donor0' 'donor1' 'donor4']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane7/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 245796, 149385
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor1' 'donor3' 'donor0' 'donor2' 'donor4']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane1/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 162195, 105155
# aligned donors:
# ['donor1' 'donor2' 'donor3' 'donor4']
# ['donor1' 'donor3' 'donor0' 'donor2']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane2/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 154986, 100921
# aligned donors:
# ['donor1' 'donor2' 'donor3' 'donor4']
# ['donor3' 'donor1' 'donor0' 'donor2']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane3/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 154462, 98837
# aligned donors:
# ['donor1' 'donor2' 'donor3' 'donor4']
# ['donor0' 'donor3' 'donor1' 'donor2']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/org3/vireo_5/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 111516, 68969
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor1' 'donor2' 'donor3' 'donor4' 'donor0']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz', 
                                     '/media/chang/HDD-3/chang/david/org3/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 111516, 68969
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor3' 'donor2' 'donor0' 'donor1']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC10/vireo/GT_donors.vireo.vcf.gz', 
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 411985, 130867
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor0' 'donor6' 'donor5' 'donor3' 'donor1']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC11/vireo/GT_donors.vireo.vcf.gz', 
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 387543, 131138
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor1' 'donor5' 'donor0' 'donor3' 'donor6']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithAB2/vireo/GT_donors.vireo.vcf.gz', 
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 412981, 129312
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4']
# ['donor2' 'donor7' 'donor6' 'donor0' 'donor4']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC10/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC11/vireo/GT_donors.vireo.vcf.gz', 
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (411985, 7, 3)
# Shape for Geno Prob in VCF2: (411985, 7, 3)
# n_variants in VCF1, VCF2 and matchd: 411985, 387543, 307683
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4' 'donor5' 'donor6']
# ['donor1' 'donor6' 'donor4' 'donor3' 'donor7' 'donor0' 'donor5']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC10/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithAB2/vireo/GT_donors.vireo.vcf.gz', 
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (411985, 7, 3)
# Shape for Geno Prob in VCF2: (411985, 7, 3)
# n_variants in VCF1, VCF2 and matchd: 411985, 412981, 323972
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4' 'donor5' 'donor6']
# ['donor2' 'donor4' 'donor3' 'donor0' 'donor5' 'donor6' 'donor7']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC11/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithAB2/vireo/GT_donors.vireo.vcf.gz', 
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (387543, 8, 3)
# Shape for Geno Prob in VCF2: (387543, 8, 3)
# n_variants in VCF1, VCF2 and matchd: 387543, 412981, 324300
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3' 'donor4' 'donor5' 'donor6' 'donor7']
# ['donor6' 'donor2' 'donor1' 'donor0' 'donor3' 'donor7' 'donor4' 'donor5']

# %%
#7215-34,3577-3,AB-2,WTC10,28126,13234,WTC11,6OC2,5401-35,20961B
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/org_1_2/org_1/outs/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/latest_org/DSTJN01/ThalOrgWithWTC10/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (53976, 4, 3)
# Shape for Geno Prob in VCF2: (53976, 4, 3)
# n_variants in VCF1, VCF2 and matchd: 53976, 411985, 46914
# aligned donors:
# ['donor0' 'donor1' 'donor2' 'donor3']
# ['donor1' 'donor6' 'donor2' 'donor0']

# %%
res = vireoSNP.vcf.match_VCF_samples('/media/chang/HDD-3/chang/david/DS_org_fastq/DS_Lane4/vireo/GT_donors.vireo.vcf.gz',
                                     '/media/chang/HDD-3/chang/david/DS_org/org_cr/outs/vireo/GT_donors.vireo.vcf.gz',
                                     GT_tag1 = 'PL', GT_tag2='PL')

fig = plt.figure()
vireoSNP.plot.heat_matrix(res['matched_GPb_diff'], 
                          res['matched_donors1'] , 
                          res['matched_donors2'] )
plt.title("Geno Prob Delta: %d SNPs" %(res['matched_n_var']))
plt.tight_layout()
plt.show()
# Out:
# Shape for Geno Prob in VCF1: (164415, 5, 3)
# Shape for Geno Prob in VCF2: (164415, 5, 3)
# n_variants in VCF1, VCF2 and matchd: 164415, 374940, 136284
# aligned donors:
# ['donor0' 'donor1' 'donor2']
# ['donor0' 'donor2' 'donor1']
